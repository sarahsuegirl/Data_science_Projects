# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_csv('WorldBank_GDP.csv')
df1
# Out:
#      Country Name Country Code     Indicator Name  Year           GDP
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12
# 11  United States          USA  GDP (current US$)  2012  1.619700e+13
# ...

# %%
df1.head()
# Out:
#     Country Name Country Code     Indicator Name  Year           GDP
# 0          China          CHN  GDP (current US$)  2010  6.087160e+12
# 1        Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2          Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3  United States          USA  GDP (current US$)  2010  1.499210e+13
# 4          China          CHN  GDP (current US$)  2011  7.551500e+12

# %%
df2.head()
# Out:
#   Country Name Country Code     Indicator Name  Year         Pop
# 0        Aruba          ABW  Population, total  2010    101669.0
# 1  Afghanistan          AFG  Population, total  2010  29185507.0
# 2       Angola          AGO  Population, total  2010  23356246.0
# 3      Albania          ALB  Population, total  2010   2913021.0
# 4      Andorra          AND  Population, total  2010     84449.0

# %%
df1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Year', 'GDP'], dtype='object')

# %%
df2=pd.read_csv('WorldBank_POP.csv')
df2
# Out:
#       Country Name Country Code     Indicator Name  Year         Pop
# 0            Aruba          ABW  Population, total  2010    101669.0
# 1      Afghanistan          AFG  Population, total  2010  29185507.0
# 2           Angola          AGO  Population, total  2010  23356246.0
# 3          Albania          ALB  Population, total  2010   2913021.0
# 4          Andorra          AND  Population, total  2010     84449.0
# ...            ...          ...                ...   ...         ...
# 2635        Kosovo          XKX  Population, total  2018   1845300.0
# 2636   Yemen, Rep.          YEM  Population, total  2018  28498687.0
# 2637  South Africa          ZAF  Population, total  2018  57779622.0
# 2638        Zambia          ZMB  Population, total  2018  17351822.0
# 2639      Zimbabwe          ZWE  Population, total  2018  14439018.0
#
# [2640 rows x 5 columns]

# %%
df2.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Indicator_Name', 'Year', 'Pop'], dtype='object')

# %%
df1['Pop']=df1['GDP'].rename('Pop')
df1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Year', 'GDP', 'Pop'], dtype='object')

# %%
# Out:
#       Country Name Country Code     Indicator Name  Year         Pop
# 0            Aruba          ABW  Population, total  2010    101669.0
# 1      Afghanistan          AFG  Population, total  2010  29185507.0
# 2           Angola          AGO  Population, total  2010  23356246.0
# 3          Albania          ALB  Population, total  2010   2913021.0
# 4          Andorra          AND  Population, total  2010     84449.0
# ...            ...          ...                ...   ...         ...
# 2635        Kosovo          XKX  Population, total  2018   1845300.0
# 2636   Yemen, Rep.          YEM  Population, total  2018  28498687.0
# 2637  South Africa          ZAF  Population, total  2018  57779622.0
# 2638        Zambia          ZMB  Population, total  2018  17351822.0
# 2639      Zimbabwe          ZWE  Population, total  2018  14439018.0
#
# [2640 rows x 5 columns]

# %%
df1.rename(columns={'Country Name':'Country_Name','Country Code':'Country_Code','Indicator Name':'Indicator_Name'},inplace=True)

# %%
df1.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Indicator_Name', 'Year', 'GDP', 'Pop'], dtype='object')

# %%
df1.drop(columns='GDP',axis=1)
# Out:
#      Country_Name Country_Code     Indicator_Name  Year           Pop
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12
# 11  United States          USA  GDP (current US$)  2012  1.619700e+13
# ...

# %%
df1.shape
# Out:
# (40, 6)

# %%
df2.shape
# Out:
# (2640, 5)

# %%
df2.rename(columns={'Country Name':'Country_Name','Country Code':'Country_Code','Indicator Name':'Indicator_Name'},inplace=True)

# %%
df2.columns
# Out:
# Index(['Country_Name', 'Country_Code', 'Indicator_Name', 'Year', 'Pop'], dtype='object')

# %%
#why is not showing???

df=df1.merge(df2,how='inner')
df
# Out:
# Empty DataFrame
# Columns: [Country_Name, Country_Code, Indicator_Name, Year, GDP, Pop]
# Index: []

# %%
df_outer=df1.merge(df2,how='outer')
df_outer
# Out:
#        Country_Name Country_Code     Indicator_Name  Year           GDP  \
# 0             China          CHN  GDP (current US$)  2010  6.087160e+12
# 1           Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2             Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3     United States          USA  GDP (current US$)  2010  1.499210e+13
# 4             China          CHN  GDP (current US$)  2011  7.551500e+12
# ...             ...          ...                ...   ...           ...
# 2675         Kosovo          XKX  Population, total  2018           NaN
# 2676    Yemen, Rep.          YEM  Population, total  2018           NaN
# 2677   South Africa          ZAF  Population, total  2018           NaN
# 2678         Zambia          ZMB  Population, total  2018           NaN
# 2679       Zimbabwe          ZWE  Population, total  2018           NaN
#
#                Pop
# 0     6.087160e+12
# 1     3.417090e+12
# 2     5.700100e+12
# 3     1.499210e+13
# ...

# %%
#why it is 12672???

df_year=df1.merge(df2,how='outer',on='Year')
df_year
# Out:
#       Country_Name_x Country_Code_x   Indicator_Name_x  Year           GDP  \
# 0              China            CHN  GDP (current US$)  2010  6.087160e+12
# 1              China            CHN  GDP (current US$)  2010  6.087160e+12
# 2              China            CHN  GDP (current US$)  2010  6.087160e+12
# 3              China            CHN  GDP (current US$)  2010  6.087160e+12
# 4              China            CHN  GDP (current US$)  2010  6.087160e+12
# ...              ...            ...                ...   ...           ...
# 12667  United States            USA  GDP (current US$)  2018  2.049410e+13
# 12668  United States            USA  GDP (current US$)  2018  2.049410e+13
# 12669  United States            USA  GDP (current US$)  2018  2.049410e+13
# 12670  United States            USA  GDP (current US$)  2018  2.049410e+13
# 12671  United States            USA  GDP (current US$)  2018  2.049410e+13
#
# ...

# %%
#How can I see all the years with its counts????
df_year['Year'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        2010
# 1        2010
# 2        2010
# 3        2010
# 4        2010
#          ...
# 12667    2018
# 12668    2018
# 12669    2018
# 12670    2018
# 12671    2018
# Name: Year, Length: 12672, dtype: int64>

# %%
sns.countplot(data=df_year, x='Year')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
df.shape
# Out:
# (12672, 9)

# %%
df_year.groupby('Year').count()
# Out:
#       Country_Name_x  Country_Code_x  Indicator_Name_x   GDP  Pop_x  \
# Year
# 2010            1056            1056              1056  1056   1056
# 2011            1056            1056              1056  1056   1056
# 2012            4224            4224              4224  4224   4224
# 2013            1056            1056              1056  1056   1056
# 2014            1056            1056              1056  1056   1056
# 2015            1056            1056              1056  1056   1056
# 2016            1056            1056              1056  1056   1056
# 2017            1056            1056              1056  1056   1056
# 2018            1056            1056              1056  1056   1056
#
#       Country_Name_y  Country_Code_y  Indicator_Name_y  Pop_y
# Year
# 2010            1056            1056              1056   1052
# 2011            1056            1056              1056   1052
# 2012            4224            4224              4224   4192
# ...

# %%
df_year.groupby('Year').get_group(2010)
# Out:
#      Country_Name_x Country_Code_x   Indicator_Name_x  Year           GDP  \
# 0             China            CHN  GDP (current US$)  2010  6.087160e+12
# 1             China            CHN  GDP (current US$)  2010  6.087160e+12
# 2             China            CHN  GDP (current US$)  2010  6.087160e+12
# 3             China            CHN  GDP (current US$)  2010  6.087160e+12
# 4             China            CHN  GDP (current US$)  2010  6.087160e+12
# ...             ...            ...                ...   ...           ...
# 1051  United States            USA  GDP (current US$)  2010  1.499210e+13
# 1052  United States            USA  GDP (current US$)  2010  1.499210e+13
# 1053  United States            USA  GDP (current US$)  2010  1.499210e+13
# 1054  United States            USA  GDP (current US$)  2010  1.499210e+13
# 1055  United States            USA  GDP (current US$)  2010  1.499210e+13
#
#              Pop_x Country_Name_y Country_Code_y   Indicator_Name_y  \
# ...

# %%
df1.sample()
# Out:
#    Country Name Country Code     Indicator Name  Year           GDP
# 29      Germany          DEU  GDP (current US$)  2016  3.495160e+12

# %%
df2.sample()
# Out:
#     Country Name Country Code     Indicator Name  Year         Pop
# 879       Greece          GRC  Population, total  2012  11045011.0

# %%
df1['Year'].value_counts()
# Out:
# 2012    8
# 2010    4
# 2011    4
# 2013    4
# 2014    4
# 2015    4
# 2016    4
# 2017    4
# 2018    4
# Name: Year, dtype: int64

# %%
df1['Year'].duplicated().sum()
# Out:
# 31

# %%
df1.drop_duplicates(inplace=True)

# %%
df1['Year'].value_counts()
# Out:
# 2010    4
# 2011    4
# 2012    4
# 2013    4
# 2014    4
# 2015    4
# 2016    4
# 2017    4
# 2018    4
# Name: Year, dtype: int64

# %%
df2['Year'].value_counts()
# Out:
# 2012    528
# 2010    264
# 2011    264
# 2013    264
# 2014    264
# 2015    264
# 2016    264
# 2017    264
# 2018    264
# Name: Year, dtype: int64

# %%
df2['Year'].duplicated().sum()
# Out:
# 2631

# %%
df2.drop_duplicates(inplace=True)

# %%
df2['Year'].value_counts()
# Out:
# 2010    264
# 2011    264
# 2012    264
# 2013    264
# 2014    264
# 2015    264
# 2016    264
# 2017    264
# 2018    264
# Name: Year, dtype: int64

# %%
df1['Country Name'].value_counts()
# Out:
# China            9
# Germany          9
# Japan            9
# United States    9
# Name: Country Name, dtype: int64

# %%
df2['Country Name'].value_counts()
# Out:
# Aruba                                     9
# Other small states                        9
# Malaysia                                  9
# North America                             9
# Namibia                                   9
#                                          ..
# High income                               9
# Hong Kong SAR, China                      9
# Honduras                                  9
# Heavily indebted poor countries (HIPC)    9
# Zimbabwe                                  9
# Name: Country Name, Length: 264, dtype: int64

# %%
df1.shape
# Out:
# (36, 5)

# %%
df2.shape
# Out:
# (2376, 5)

# %%
df1.merge(df2,how='inner',on=['Country Name','Year'])
# Out:
#      Country Name Country Code_x   Indicator Name_x  Year           GDP  \
# 0           China            CHN  GDP (current US$)  2010  6.087160e+12
# 1         Germany            DEU  GDP (current US$)  2010  3.417090e+12
# 2           Japan            JPN  GDP (current US$)  2010  5.700100e+12
# 3   United States            USA  GDP (current US$)  2010  1.499210e+13
# 4           China            CHN  GDP (current US$)  2011  7.551500e+12
# 5         Germany            DEU  GDP (current US$)  2011  3.757700e+12
# 6           Japan            JPN  GDP (current US$)  2011  6.157460e+12
# 7   United States            USA  GDP (current US$)  2011  1.554260e+13
# 8           China            CHN  GDP (current US$)  2012  8.532230e+12
# 9         Germany            DEU  GDP (current US$)  2012  3.543980e+12
# 10          Japan            JPN  GDP (current US$)  2012  6.203210e+12
# 11  United States            USA  GDP (current US$)  2012  1.619700e+13
# ...

# %%
df1.merge(df2,how='outer',on=['Country Name','Year']).drop('Country Code_y','Indicator Name_y'])
# Out:
#        Country Name Country Code_x   Indicator Name_x  Year           GDP  \
# 0             China            CHN  GDP (current US$)  2010  6.087160e+12
# 1           Germany            DEU  GDP (current US$)  2010  3.417090e+12
# 2             Japan            JPN  GDP (current US$)  2010  5.700100e+12
# 3     United States            USA  GDP (current US$)  2010  1.499210e+13
# 4             China            CHN  GDP (current US$)  2011  7.551500e+12
# ...             ...            ...                ...   ...           ...
# 2371         Kosovo            NaN                NaN  2018           NaN
# 2372    Yemen, Rep.            NaN                NaN  2018           NaN
# 2373   South Africa            NaN                NaN  2018           NaN
# 2374         Zambia            NaN                NaN  2018           NaN
# 2375       Zimbabwe            NaN                NaN  2018           NaN
#
#      Country Code_y   Indicator Name_y           Pop
# ...

# %%
pip install category_encoders
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#      -------------------------------------- 81.9/81.9 kB 306.4 kB/s eta 0:00:00
# ...

# %%
from category_encoders.binary import BinaryEncoder

# %%
BC=BinaryEncoder()

# %%
BC.fit_transform(df1[['Country Name']])
# Out:
#     Country Name_0  Country Name_1  Country Name_2
# 0                0               0               1
# 1                0               1               0
# 2                0               1               1
# 3                1               0               0
# 4                0               0               1
# 5                0               1               0
# 6                0               1               1
# 7                1               0               0
# 8                0               0               1
# 9                0               1               0
# 10               0               1               1
# 11               1               0               0
# 16               0               0               1
# 17               0               1               0
# 18               0               1               1
# 19               1               0               0
# 20               0               0               1
# ...

# %%
BinaryEncoder(cols=df1['Country Name'])
# Out:
# BinaryEncoder(cols=0             China
# 1           Germany
# 2             Japan
# 3     United States
# 4             China
# 5           Germany
# 6             Japan
# 7     United States
# 8             China
# 9           Germany
# 10            Japan
# 11    United States
# 16            China
# 17          Germany
# 18            Japan
# 19    United States
# 20            China
# 21          Germany
# 22            Japan
# 23    United States
# 24            China
# 25          Germany
# 26            Japan
# 27    United States
# 28            China
# 29          Germany
# 30            Japan
# 31    United States
# 32            China
# 33          Germany
# 34            Japan
# 35    United States
# 36            China
# 37          Germany
# 38            Japan
# 39    United States
# Name: Country Name, dtype: object)
